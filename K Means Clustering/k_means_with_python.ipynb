# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.datasets import make_blobs

# %%
data = make_blobs(n_samples=200, n_features=2, centers=4, cluster_std=1.8, random_state=101)

# %%
plt.scatter(data[0][:,0], data[0][:,1], c=data[1], cmap='rainbow')

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=8)

# %%
kmeans.fit(data[0])
# Out:
# KMeans()

# %%
kmeans.cluster_centers_
# Out:
# array([[ -4.28578036,   8.07272556],
#        [ -8.92965249,  -7.74388679],
#        [  4.03349713,   8.3407464 ],
#        [ -1.57897171,   2.1617459 ],
#        [  0.72234734,   5.64544902],
#        [  1.44485992,   0.48836322],
#        [-10.35008901,  -4.63054116],
#        [  5.10828057,   4.90813315]])

# %%
kmeans.labels_
# Out:
# array([0, 7, 3, 2, 2, 6, 2, 3, 4, 3, 0, 3, 2, 4, 0, 5, 7, 3, 6, 0, 6, 5,
#        4, 1, 0, 1, 1, 5, 2, 7, 0, 1, 7, 5, 3, 0, 6, 6, 1, 5, 1, 0, 0, 0,
#        3, 4, 0, 4, 1, 4, 5, 0, 7, 5, 1, 4, 4, 5, 0, 2, 1, 4, 6, 0, 2, 3,
#        6, 7, 2, 1, 2, 4, 6, 3, 1, 7, 2, 3, 0, 3, 3, 1, 2, 1, 5, 3, 3, 0,
#        4, 6, 1, 1, 6, 4, 4, 1, 2, 0, 1, 7, 3, 6, 4, 3, 4, 3, 6, 2, 1, 1,
#        7, 0, 0, 2, 1, 7, 0, 0, 4, 0, 4, 0, 3, 0, 3, 7, 0, 3, 1, 0, 0, 0,
#        5, 1, 6, 0, 7, 3, 2, 5, 1, 7, 6, 4, 0, 4, 4, 1, 0, 0, 0, 0, 3, 7,
#        5, 0, 4, 2, 2, 5, 2, 5, 3, 0, 6, 0, 3, 2, 0, 5, 2, 5, 0, 4, 4, 0,
#        2, 4, 1, 4, 0, 1, 1, 0, 6, 1, 6, 1, 1, 5, 6, 2, 2, 0, 1, 4, 2, 2,
#        6, 5], dtype=int32)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, sharey=True, figsize = (10, 6))

ax1.set_title('K Means')
ax1.scatter(data[0][:, 0], data[0][:, 1], c=kmeans.labels_, cmap='rainbow')

ax2.set_title('Original')
ax2.scatter(data[0][:, 0], data[0][:, 1], c=data[1], cmap='rainbow')
